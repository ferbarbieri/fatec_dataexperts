# %% [markdown]
# ### Exercício Pandas

# %%
import pandas as pd

# %%
# Lendo um arquivo CSV
df_vendas = pd.read_csv(r'datasets\TABELA_VENDAS.csv')

df_vendas.head()
# Out:
#     Categoria            SubCategoria        Modelo       Cor Tamanho  \
# 0  Bicicletas  Bicicletas de montanha  Mountain-100     Prata      48
# 1  Bicicletas   Bicicletas de estrada      Road-150  Vermelho      62
# 2  Bicicletas   Bicicletas de estrada      Road-150  Vermelho      52
# 3  Bicicletas  Bicicletas de montanha  Mountain-100     Preto      38
# 4  Bicicletas   Bicicletas de estrada      Road-150  Vermelho      48
#
#   Preço Custo Unit Data Pedido    Pais               Estado  UF  \
# 0          1912,15  01/07/2017  Brasil              Paraíba  PB
# 1          2171,29  01/07/2017  Brasil         Minas Gerais  MG
# 2          2171,29  01/07/2017  Brasil              Alagoas  AL
# 3          1898,09  01/07/2017  Brasil                Ceará  CE
# 4          2171,29  01/08/2017  Brasil  Rio Grande do Norte  RN
#
#           Cidade    Região  Pedidos Qtd Total Venda  ID_VENDA
# 0       Passagem  Nordeste            2     6799,98         1
# ...

# %%
# Todas as Bicicletas Vermelhas

biciletas_vermelhas = df_vendas[(df_vendas['Categoria'] == 'Bicicletas') & (df_vendas['Cor'] == 'Vermelho')]

biciletas_vermelhas = biciletas_vermelhas[['Categoria', 'Modelo', 'Cor']].drop_duplicates()

biciletas_vermelhas
# Out:
#      Categoria    Modelo       Cor
# 1   Bicicletas  Road-150  Vermelho
# 8   Bicicletas  Road-650  Vermelho
# 46  Bicicletas  Road-250  Vermelho
