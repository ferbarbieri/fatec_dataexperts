# %% [markdown]
# # Análise de Dados em Python
#
# ## Formação DataExperts - DEMO - Análise de Laptops

# %% [markdown]
# ### Instalar packages

# %%
# !pip install seaborn
# !pip install scikit-learn

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataframe com dataset
#
# - Origem [Laptops Price Dataset](https://www.kaggle.com/datasets/juanmerinobermejo/laptops-price-dataset?resource=download)

# %%
#df = pd.read_csv('laptops.csv', encoding='ISO-8859-1', index_col=0)
df = pd.read_csv('datasets/laptops.csv')

df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
# Linhas x Colunas
df.shape
# Out:
# (2160, 12)

# %%
df.count()
# Out:
# Laptop          2160
# Status          2160
# Brand           2160
# Model           2160
# CPU             2160
# RAM             2160
# Storage         2160
# Storage type    2118
# GPU              789
# Screen          2156
# Touch           2160
# Final Price     2160
# dtype: int64

# %%
# Dados sobre as colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %%
df.sample(10)
#df.head(10)
#df.tail(10)
# Out:
#                                                  Laptop       Status  \
# 361   ASUS ROG Strix Scar 18 2023 G834JZ-N6004W Inte...          New
# 1557  Lenovo ThinkPad T15 Gen 2 Intel Core i7-1165G7...          New
# 1618  Microsoft Surface Go 3 Business 4G LTE Intel C...          New
# 220   MSI Bravo 15 B5ED-018XES AMD Ryzen 7 5800H/16G...          New
# 1771  Asus Chromebook 14 C424MA-EB0088 Intel Celeron...  Refurbished
# 1024  Dell Vostro 5320 Intel Evo Core i7-1260P/16GB/...          New
# 2078  MSI Modern 15 A11SB-858XES Intel Core i7-1195G...  Refurbished
# 1213  ASUS Chromebook Flip CX5 CB5400FMA Intel Core ...          New
# 1107  ASUS ZenBook 14 UM425UAZ-KI016W AMD Ryzen 7 57...  Refurbished
# 1462  HP Victus 16-E0098NS AMD Ryzen 7 5800H/16GB/51...          New
#
#           Brand       Model                CPU  RAM  Storage Storage type  \
# 361        Asus         ROG      Intel Core i9   32     1000          SSD
# 1557     Lenovo    ThinkPad      Intel Core i7   16      512          SSD
# 1618  Microsoft  Surface Go      Intel Core i3    8      256          SSD
# 220         MSI       Bravo        AMD Ryzen 7   16      512          SSD
# 1771       Asus  Chromebook      Intel Celeron    8       64         eMMC
# 1024       Dell      Vostro  Intel Evo Core i7   16      512          SSD
# 2078        MSI      Modern      Intel Core i7   32     1000          SSD
# 1213       Asus  Chromebook      Intel Core i7    8      256          SSD
# 1107       Asus     ZenBook        AMD Ryzen 7   16      512          SSD
# 1462         HP      Victus        AMD Ryzen 7   16      512          SSD
#
#            GPU  Screen Touch  Final Price
# 361   RTX 4080    18.0    No      3399.00
# 1557       NaN    15.6    No      1506.99
# 1618       NaN    10.5   Yes       957.81
# 220   RX 6500M    15.6    No       999.00
# 1771       NaN    14.0    No       399.00
# 1024       NaN    13.3    No      1216.00
# 2078    MX 450    15.6    No      1399.00
# 1213       NaN    14.0    No       918.00
# 1107       NaN    14.0    No       849.00
# 1462  RTX 3050    16.1    No       998.56

# %% [markdown]
# ### Renomear Colunas

# %%
df = df.rename(columns={'Brand' : 'Marca', 
                        'Model' : 'Modelo',
                        'Screen' : 'Tela',
                        'Final Price':'Valor'})
df
# Out:
#                                                  Laptop       Status   Marca  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
#           Modelo                CPU  RAM  Storage Storage type       GPU  \
# 0     ExpertBook      Intel Core i5    8      512          SSD       NaN
# 1             Go      Intel Celeron    8      256          SSD       NaN
# 2     ExpertBook      Intel Core i3    8      256          SSD       NaN
# 3         Katana      Intel Core i7   16     1000          SSD  RTX 3050
# 4            15S      Intel Core i5   16      512          SSD       NaN
# ...          ...                ...  ...      ...          ...       ...
# 2155       Blade      Intel Core i7   16     1000          SSD  RTX 3060
# 2156       Blade      Intel Core i7   16     1000          SSD  RTX 3070
# 2157       Blade      Intel Core i7   32     1000          SSD  RTX 3080
# 2158        Book  Intel Evo Core i7   16     1000          SSD       NaN
# 2159        Book  Intel Evo Core i7   16      256          SSD       NaN
#
#       Tela Touch    Valor
# 0     15.6    No  1009.00
# 1     15.6    No   299.00
# 2     15.6    No   789.00
# 3     15.6    No  1199.00
# 4     15.6    No   669.01
# ...    ...   ...      ...
# 2155  17.3    No  2699.99
# 2156  17.3    No  2899.99
# 2157  17.3    No  3399.99
# 2158  13.4   Yes  1899.99
# 2159  13.4   Yes  1699.99
#
# [2160 rows x 12 columns]

# %% [markdown]
# ### Limpeza dos dados

# %%
''' Remoção de colunas não utilizadas
     -inplace True aplica no dataframe atual, False retorna uma cópia
     - axis: columns ou 1 aplica nas colunas, 0 ou index aplica no índice '''
    
df.drop(['Status', 'Touch'], inplace=True, axis='columns')
df.shape
# Out:
# (2160, 10)

# %%
# dados nulos
df.isnull().sum()
# Out:
# Laptop             0
# Marca              0
# Modelo             0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Tela               4
# Valor              0
# dtype: int64

# %% [markdown]
# - Não vou remover a coluna GPU, mesmo contendo muitos nulos pois quero saber quantos laptops possuem ou não uma GPU dedicada

# %% [markdown]
# ### Padronização

# %%
#Ajuste a GPU para listar as integradas ao invés de null
df['GPU'].fillna('Integrada', inplace=True)

# %% [markdown]
# ## Análise

# %% [markdown]
# ### Dados únicos

# %%
df.nunique()
# Out:
# Laptop          2160
# Marca             27
# Modelo           121
# CPU               28
# RAM                9
# Storage           12
# Storage type       2
# GPU               45
# Tela              29
# Valor           1440
# dtype: int64

# %% [markdown]
# ### # de Laptops por marca

# %%
df.Marca.value_counts()
# Out:
# Marca
# Asus         415
# HP           368
# Lenovo       366
# MSI          308
# Acer         137
# Apple        116
# Dell          84
# Microsoft     77
# Gigabyte      48
# Razer         37
# Name: count, dtype: int64

# %% [markdown]
# ### Estatísticas

# %%
#Média de preços
print(df['Valor'].mean())

#Mediana
print(df['Valor'].median())

#Desvio padrão
print(df['Valor'].std())
# Out:
# 1312.638509259259
# 1031.9450000000002
# 911.4754170328499

# %% [markdown]
# ### Gráfico por marca

# %%
plt.figure(figsize=(10,5))

df['Marca'].value_counts().plot(kind='bar')

plt.title('Laptops por marca', fontsize=10)

plt.xlabel('Marca', fontsize=15)
plt.ylabel('Quantidade', fontsize=12)
plt.show()

# %% [markdown]
# ### Remover os itens com menos modelos

# %%
itens_a_remover = df['Marca'].value_counts()[df['Marca'].value_counts() < 35].index

df = df[~df['Marca'].isin(itens_a_remover)]

# %%
plt.figure(figsize=(12,8))

df['Marca'].value_counts().plot(kind='bar')

plt.title('Laptops por marca', fontsize=12)

plt.xlabel('Marca', fontsize=15)
plt.ylabel('Quantidade', fontsize=12)
plt.show()

# %% [markdown]
# ### Laptops por placa de vídeo

# %%
df['GPU'].value_counts()
# Out:
# GPU
# Integrada             1220
# RTX 3060               117
# RTX 3050               109
# RTX 3070                95
# RTX 3080                51
# RTX 4060                51
# GTX 1650                50
# RTX 4070                39
# RTX 4050                29
# RTX 2070                24
# RTX 2060                20
# RTX 4080                17
# RTX 4090                16
# GTX 1660                11
# RTX 2050                 9
# Radeon Pro 5500M         9
# RTX A2000                8
# RTX 2080                 7
# RTX A3000                7
# MX 450                   7
# RTX A1000                6
# T 1200                   6
# MX 550                   5
# MX 330                   5
# T 500                    5
# T 550                    4
# RTX A5500                3
# RX 6500M                 3
# Radeon Pro RX 560X       3
# RX 7600S                 2
# Radeon Pro 5300M         2
# GTX 1050                 2
# T 600                    2
# 610 M                    2
# RX 6700M                 1
# P 500                    1
# MX 130                   1
# T 2000                   1
# RX 6800S                 1
# A 370M                   1
# RTX 3000                 1
# Radeon RX 6600M          1
# T 1000                   1
# GTX 1070                 1
# Name: count, dtype: int64

# %%
# Quais notebooks tem uma 4090?

df[df.GPU == 'RTX 4090'].sort_values(by='Valor', ascending=False)

#df[(df.GPU == 'RTX 4090') | (df.GPU == 'RTX 4080')].sort_values(by='Valor', ascending=False)
# Out:
#                                                  Laptop   Marca   Modelo  \
# 478   MSI Titan GT77 HX 13VI-006ES Intel Core i9-139...     MSI    Titan
# 1202  ASUS ROG Strix SCAR 18 G834JY-93B49PB1 Intel C...    Asus      ROG
# 1245  ASUS ROG Strix Scar 17  G733PY-R97B49PB1 AMD R...    Asus      ROG
# 952   MSI Raider GE78HX 13VI-063ES Intel Core i9-139...     MSI   Raider
# 495   ASUS ROG Zephyrus Duo 16 2023 GX650PY-NM003W A...    Asus      ROG
# 550   Razer Blade 16 Doble Resolución UHD+/FHD+ Inte...   Razer    Blade
# 1606  MSI Titan GT77 HX 13VI-007ES Intel Core i9-139...     MSI    Titan
# 406   ASUS ROG Strix Scar 16 2023 G634JY-NM014W Inte...    Asus      14w
# 695   ASUS ROG Zephyrus G14 2023 GA402XY-NC019W AMD ...    Asus      ROG
# 414   ASUS ROG Zephyrus M16 2023 GU604VY-NM001W Inte...    Asus      ROG
# 763   Lenovo Legion Pro 7 16IRX8H Intel Core i9-1390...  Lenovo   Legion
# 1601  MSI Raider GE78HX 13VI-201ES Intel Core i7-137...     MSI   Raider
# 446   MSI Stealth 17 Studio A13VI-030ES Intel Core i...     MSI  Stealth
# 292   ASUS ROG Strix Scar 16 2023 G634JY-N4013 Intel...    Asus      ROG
# 307   ASUS ROG Strix Scar 18 2023 G834JY-N5012 Intel...    Asus      ROG
# 903   ASUS ROG Strix SCAR 17 2023 G733PY-LL002 AMD R...    Asus      ROG
#
#                 CPU  RAM  Storage Storage type       GPU  Tela    Valor
# 478   Intel Core i9  128     2000          SSD  RTX 4090  17.3  5999.00
# 1202  Intel Core i9   64     2000          SSD  RTX 4090  16.0  5758.14
# 1245   AMD Radeon 9   32     2000          SSD  RTX 4090  17.3  5630.90
# 952   Intel Core i9   64     2000          SSD  RTX 4090  17.0  5199.00
# 495     AMD Ryzen 9   64     2000          SSD  RTX 4090  16.0  5159.00
# 550   Intel Core i9   32     2000          SSD  RTX 4090  16.0  4999.01
# 1606  Intel Core i9   64     2000          SSD  RTX 4090  17.3  4993.11
# 406   Intel Core i9   32     2000          SSD  RTX 4090  16.0  4949.01
# 695     AMD Ryzen 9   32     1000          SSD  RTX 4090  14.0  4599.00
# 414   Intel Core i9   32     2000          SSD  RTX 4090  16.0  4299.00
# 763   Intel Core i9   32     1000          SSD  RTX 4090  16.0  4199.00
# 1601  Intel Core i7   32     1000          SSD  RTX 4090  17.0  3864.40
# 446   Intel Core i7   32     1000          SSD  RTX 4090  17.3  3818.77
# 292   Intel Core i9   32     1000          SSD  RTX 4090  16.0  3699.01
# 307   Intel Core i9   32     1000          SSD  RTX 4090  18.0  3699.01
# 903     AMD Ryzen 9   32     1000          SSD  RTX 4090  17.3  3258.19

# %% [markdown]
# ### Gráfico das GPUs

# %%
# Top 10 de GPUs
df.GPU.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='GPU'>

# %%
df_gpu=df['GPU'].value_counts()

plt.figure(figsize=(7, 5))
plt.pie(df_gpu,labels=df_gpu.index,autopct='%1.f%%')
plt.title('Distribuição de GPUs')
plt.show()

# %%
# Agrupar todos os itens menores de 10 em uma categoria OUTROS

df_gpu = df['GPU'].value_counts()

regra_agrupamento = df_gpu[df_gpu < 10].index

# Usa uma lambda pra pegar todos os itens menores do que a regra e agrupar
df['GPU_agrupada'] = df['GPU'].apply(lambda x: 'Outros' if x in regra_agrupamento else x)

# Conta o número de ocorrências após o agrupamento
df_gpu_agrupada = df['GPU_agrupada'].value_counts()

# Configuração do gráfico de pizza
plt.figure(figsize=(7, 5))
plt.pie(df_gpu_agrupada, labels=df_gpu_agrupada.index, autopct='%1.f%%')
plt.title('Distribuição de GPUs')
plt.show()

# %% [markdown]
# ### Distribuição de preços

# %%
df[['Valor']].boxplot()
# Out:
# <Axes: >

# %%
#Agrupado por marca

df.boxplot(by = 'Marca', column = ['Valor'], grid=False, figsize=(12,8))
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='Marca'>

# %%
plt.figure(figsize=(12,8))

sns.swarmplot(x='Marca', y='Valor', data=df, size=2)
#sns.boxplot(x='Marca', y='Valor', data=df)

plt.show()

# %%
plt.figure(figsize=(12,8))
sns.stripplot(x='Marca', y='Valor', data=df, jitter=True, size=3) 
plt.show()

# %% [markdown]
# ### Número de modelos por marca

# %%
plt.figure(figsize=(12,4))
models_count = df.groupby('Marca')['Modelo'].nunique().reset_index(name='Count')

plt.bar(models_count['Marca'], models_count['Count'])
plt.show()

# %%
models_count
# Out:
#        Marca  Count
# 0       Acer     10
# 1      Apple      3
# 2       Asus     20
# 3       Dell      4
# 4   Gigabyte      6
# 5         HP     18
# 6     Lenovo     16
# 7        MSI     20
# 8  Microsoft      3
# 9      Razer      2

# %% [markdown]
# ### Valor médio por marca

# %%
plt.figure(figsize=(12,4))

precos_medios = df.groupby('Marca')['Valor'].mean().reset_index()

plt.bar(precos_medios['Marca'], precos_medios['Valor'])

# Ordena pelo maior valor e pega os primeiros
#marcas_por_preco = precos_medios.nlargest(6, 'Valor')
#plt.bar(marcas_por_preco['Marca'], marcas_por_preco['Valor'])


plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Agregação com a média de valor entre duas colunas do dataframe
df_agregado = df.groupby(['Marca', 'GPU'])['Valor'].mean().reset_index().nlargest(100, 'Valor')

df_pivot = df_agregado.pivot(index='Marca', columns='GPU', values='Valor')

df_pivot.fillna(0, inplace=True)

df_pivot.sample(5)
# Out:
# GPU       A 370M     GTX 1650    Integrada  MX 450   MX 550     RTX 2050  \
# Marca
# Apple        0.0     0.000000  1568.208879     0.0     0.00     0.000000
# Razer        0.0     0.000000  1799.990000     0.0     0.00     0.000000
# Gigabyte     0.0     0.000000     0.000000     0.0     0.00     0.000000
# MSI          0.0  1203.745625  1132.478077     0.0     0.00  1282.333333
# Acer         0.0     0.000000     0.000000     0.0  1209.01     0.000000
#
# GPU       RTX 2060   RTX 2070  RTX 2080  RTX 3000  ...  RX 6800S  RX 7600S  \
# Marca                                              ...
# Apple          0.0     0.0000      0.00      0.00  ...       0.0       0.0
# Razer          0.0     0.0000      0.00      0.00  ...       0.0       0.0
# Gigabyte       0.0  1336.5275      0.00      0.00  ...       0.0       0.0
# MSI            0.0  1412.7770   2052.72   2707.44  ...       0.0       0.0
# Acer           0.0     0.0000      0.00      0.00  ...       0.0       0.0
#
# GPU       Radeon Pro 5500M  Radeon Pro RX 560X  T 1000       T 1200  T 2000  \
# Marca
# Apple             2322.575         1266.126667     0.0     0.000000     0.0
# Razer                0.000            0.000000     0.0     0.000000     0.0
# Gigabyte             0.000            0.000000     0.0     0.000000     0.0
# MSI                  0.000            0.000000     0.0     0.000000     0.0
# Acer                 0.000            0.000000     0.0  2018.588333     0.0
#
# GPU       T 500  T 550  T 600
# Marca
# Apple       0.0    0.0    0.0
# Razer       0.0    0.0    0.0
# Gigabyte    0.0    0.0    0.0
# MSI         0.0    0.0    0.0
# Acer        0.0    0.0    0.0
#
# [5 rows x 34 columns]

# %%
f, ax = plt.subplots(figsize=(12, 4))


sns.heatmap(df_pivot, annot=False, linewidths=.5, ax=ax)
plt.title('Heatmap de Valor por GPU e Marca')
plt.show()
