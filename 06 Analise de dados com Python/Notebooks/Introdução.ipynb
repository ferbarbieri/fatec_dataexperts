# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.arange(0, 16, 0.1)
w = np.arange(0.5, 16.5, 0.1)
y = np.sin(x)
z = np.cos(x)

# %%
np.pi * 5
# Out:
# 15.707963267948966

# %%
plt.plot(x,y,x,z)
plt.show()

# %%
# %%HTML
#
# <b> teste </b>
# Out:
# <b> teste </b>

# %%
#pd.set_option('display.max_columns', 20)
pd.reset_option('max_columns')
df_resp.head(2)
# Out:
#    Respondent Hobby OpenSource        Country Student          Employment  \
# 0      101346    No         No  United States      No  Employed full-time
# 1       44791   Yes         No        Germany      No  Employed full-time
#
#                             FormalEducation  \
# 0  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0  A business discipline (ex. accounting, finance...
# 1  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0      100 to 499 employees
# 1  1,000 to 4,999 employees
#
#                                              DevType  ...  \
# 0                                 Back-end developer  ...
# 1  Back-end developer;Desktop or enterprise appli...  ...
#
#                     Exercise  Gender         SexualOrientation  \
# 0  Daily or almost every day  Female  Straight or heterosexual
# ...

# %%
df_resp[df_resp.Country == 'Germany'].Gender.value_counts()
# Out:
# Gender
# Male                                                      501
# Female                                                     22
# Non-binary, genderqueer, or gender non-conforming           3
# Male;Non-binary, genderqueer, or gender non-conforming      2
# Female;Transgender                                          2
# Transgender                                                 1
# Name: count, dtype: int64

# %%
df_resp.Gender.value_counts()
# Out:
# Gender
# Male                                                                         7237
# Female                                                                        455
# Non-binary, genderqueer, or gender non-conforming                              34
# Female;Transgender                                                             24
# Male;Non-binary, genderqueer, or gender non-conforming                         15
# Female;Male                                                                    10
# Transgender                                                                     8
# Female;Non-binary, genderqueer, or gender non-conforming                        8
# Transgender;Non-binary, genderqueer, or gender non-conforming                   7
# Male;Transgender                                                                4
# Female;Male;Transgender;Non-binary, genderqueer, or gender non-conforming       2
# ...

# %%
# %%javascript
#
#
# let nome = prompt("Digite seu nome")
# alert(nome)

# %%
df = pd.read_csv('laptops.csv', encoding='ISO-8859-1', index_col=0)

df.head()

# %%
df.shape

# %% [markdown]
# ### Quantidade de itens por marca

# %%
df.Brand.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.Brand.value_counts()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)

# %%
flights_long.sample(50)
