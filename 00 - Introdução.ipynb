# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#pd.set_option('display.max_columns', 20)
#pd.reset_option('max_columns')

# %%
x = np.arange(0, 16, 0.1)
w = np.arange(0.5, 16.5, 0.1)
y = np.sin(x)
z = np.cos(x)

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot(x,y,x,z)
plt.show()

# %%
# %%HTML
#
# <b> teste </b>
# Out:
# <b> teste </b>

# %%
# %%javascript
#
#
# let nome = prompt("Digite seu nome")
# alert(nome)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
df = pd.read_csv(r'datasets\TABELA_VENDAS.csv')

# %%
df.head(4)
# Out:
#     Categoria            SubCategoria        Modelo       Cor Tamanho  \
# 0  Bicicletas  Bicicletas de montanha  Mountain-100     Prata      48
# 1  Bicicletas   Bicicletas de estrada      Road-150  Vermelho      62
# 2  Bicicletas   Bicicletas de estrada      Road-150  Vermelho      52
# 3  Bicicletas  Bicicletas de montanha  Mountain-100     Preto      38
#
#   Preço Custo Unit Data Pedido    Pais        Estado  UF         Cidade  \
# 0          1912,15  01/07/2017  Brasil       Paraíba  PB       Passagem
# 1          2171,29  01/07/2017  Brasil  Minas Gerais  MG  Córrego Fundo
# 2          2171,29  01/07/2017  Brasil       Alagoas  AL    Quebrangulo
# 3          1898,09  01/07/2017  Brasil         Ceará  CE        Varjota
#
#      Região  Pedidos Qtd Total Venda  ID_VENDA
# 0  Nordeste            2     6799,98         1
# 1   Sudeste            1     3578,27         2
# 2  Nordeste            2     7156,54         3
# 3  Nordeste            1     3374,99         4

# %%
pedidos = df.groupby('Modelo')['Pedidos Qtd'].sum().reset_index(name='Pedidos')
top_10_pedidos = pedidos.sort_values(by='Pedidos', ascending=False).head(10)


#mostra como gráfico
top_10_pedidos.plot(kind='bar', x='Modelo', y='Pedidos')
plt.xlabel('Modelo')
plt.ylabel('Total de Pedidos')
plt.title('Top 10 Produtos com Maior Número de Pedidos')
plt.show()

# %%
bottom_10_pedidos = pedidos.sort_values(by='Pedidos', ascending=False).tail(10)


#mostra como gráfico
bottom_10_pedidos.plot(kind='bar', x='Modelo', y='Pedidos')
plt.xlabel('Modelo')
plt.ylabel('Total de Pedidos')
plt.title('Top 10 Produtos com Menor Número de Pedidos')
plt.show()
